# %%
# Import statements
import tensorflow as tf
import numpy as np
import scipy.io
import os
import matplotlib.pyplot as plt
import h5py

from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
# Plot formatting defaults
plt.rc('ytick', direction='out')
plt.rc('grid', color='w', linestyle='solid')
plt.rcParams['figure.figsize'] = [10, 8]
plt.rcParams.update({'font.size': 22})
plt.rc('xtick', direction='out')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

# %%
# Load in train and test data

mat = scipy.io.loadmat('W8_samples.mat')
W8_cell_data = mat['cell_data']

mat = scipy.io.loadmat('W9_samples.mat')
W9_cell_data = mat['cell_data']

del mat

X_train, y_train = shuffle(W8_cell_data[:,1:], W8_cell_data[:,0]*100)
X_test = W9_cell_data[:,1:]
y_test = W9_cell_data[:,0]*100

# Reshape for LSTM: shape = (# samples, # timesteps, # features)
X_train = np.transpose(np.reshape(X_train, (X_train.shape[0], 2, int(X_train.shape[1]/2))), (0, 2, 1))
X_test = np.transpose(np.reshape(X_test, (X_test.shape[0], 2, int(X_test.shape[1]/2))), (0, 2, 1))

# Downsample test by 1/10th
y_test = y_test[0::10]
X_test = X_test[0::10, :, :]

# Save dimensions for LSTM

n_samp, n_time, n_feat = X_train.shape

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (80902, 1200, 2)
# (80902,)
# (7109, 1200, 2)
# (7109,)

# %%
# Plot single training example
plt.plot(X_train[200,:,0])
plt.plot(X_train[200,:,1])
# plt.plot(test[200,0,:])
# plt.plot(test[200,1,:])
print(X_train.shape)
plt.show()
# Out:
# (80902, 1200, 2)

# %%
def build_cnn_model():
    model = keras.Sequential()
    model.add(layers.SeparableConv1D(100, 10, data_format='channels_last', padding='same'))
    model.add(layers.MaxPool1D(pool_size=(2)))
    model.add(layers.Conv1D(20, 5, padding='same'))
    model.add(layers.MaxPool1D(pool_size=(2)))
    # model.add(layers.Conv1D(10, 3, padding='same'))
    # model.add(layers.MaxPool1D(pool_size=(2)))
    # model.add(layers.BatchNormalization())
    model.add(layers.Flatten())
    model.add(layers.Dense(200, activation="relu"))
    model.add(layers.Dense(20, activation="relu"))
    model.add(layers.Dense(1, activation="linear"))
    model.compile(
        optimizer=keras.optimizers.Adam(),
        loss="mean_squared_error",
        metrics=["mean_squared_error"],
    )
    return model

# %%
cnn_model = build_cnn_model()
# # Check shape of model (need to instantiate input shape)
# cnn_model.build(input_shape=(500,1200,2))
# cnn_model.summary()
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-05-22 22:42:58.428745: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-05-22 22:42:58.428901: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
history = cnn_model.fit(X_train,
                    y_train,
                    epochs=200,
                    verbose=2,
                    batch_size=480,
                    validation_split=0.2)

# history = cnn_model.fit(X_train,
#                     y_train,
#                     epochs=100,
#                     verbose=2,
#                     batch_size=500,
#                     validation_split=0.2)
# Out:
# Epoch 1/200
# 2022-05-22 22:43:45.191846: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-05-22 22:43:45.582066: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-22 22:44:04.585780: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 135/135 - 21s - loss: 1050.6062 - mean_squared_error: 1050.6060 - val_loss: 7.0184 - val_mean_squared_error: 7.0184 - 21s/epoch - 156ms/step
# Epoch 2/200
# 135/135 - 20s - loss: 6.8876 - mean_squared_error: 6.8876 - val_loss: 6.8890 - val_mean_squared_error: 6.8890 - 20s/epoch - 146ms/step
# Epoch 3/200
# 135/135 - 19s - loss: 6.8338 - mean_squared_error: 6.8338 - val_loss: 6.9084 - val_mean_squared_error: 6.9084 - 19s/epoch - 141ms/step
# Epoch 4/200
# 135/135 - 19s - loss: 6.8251 - mean_squared_error: 6.8251 - val_loss: 6.8504 - val_mean_squared_error: 6.8504 - 19s/epoch - 140ms/step
# Epoch 5/200
# 135/135 - 19s - loss: 6.7937 - mean_squared_error: 6.7937 - val_loss: 6.7882 - val_mean_squared_error: 6.7882 - 19s/epoch - 140ms/step
# Epoch 6/200
# 135/135 - 19s - loss: 6.8632 - mean_squared_error: 6.8632 - val_loss: 6.8593 - val_mean_squared_error: 6.8593 - 19s/epoch - 139ms/step
# Epoch 7/200
# 135/135 - 19s - loss: 6.8461 - mean_squared_error: 6.8461 - val_loss: 6.7875 - val_mean_squared_error: 6.7875 - 19s/epoch - 141ms/step
# Epoch 8/200
# 135/135 - 19s - loss: 6.8695 - mean_squared_error: 6.8695 - val_loss: 6.8004 - val_mean_squared_error: 6.8004 - 19s/epoch - 140ms/step
# Epoch 9/200
# 135/135 - 20s - loss: 6.8563 - mean_squared_error: 6.8563 - val_loss: 6.7831 - val_mean_squared_error: 6.7831 - 20s/epoch - 147ms/step
# Epoch 10/200
# 135/135 - 19s - loss: 6.8696 - mean_squared_error: 6.8696 - val_loss: 6.7453 - val_mean_squared_error: 6.7453 - 19s/epoch - 140ms/step
# Epoch 11/200
# 135/135 - 19s - loss: 6.9572 - mean_squared_error: 6.9572 - val_loss: 6.9684 - val_mean_squared_error: 6.9684 - 19s/epoch - 139ms/step
# Epoch 12/200
# 135/135 - 19s - loss: 7.1604 - mean_squared_error: 7.1604 - val_loss: 7.0675 - val_mean_squared_error: 7.0675 - 19s/epoch - 140ms/step
# Epoch 13/200
# 135/135 - 19s - loss: 6.9528 - mean_squared_error: 6.9528 - val_loss: 6.8744 - val_mean_squared_error: 6.8744 - 19s/epoch - 139ms/step
# Epoch 14/200
# 135/135 - 19s - loss: 6.9261 - mean_squared_error: 6.9261 - val_loss: 6.7715 - val_mean_squared_error: 6.7715 - 19s/epoch - 140ms/step
# Epoch 15/200
# 135/135 - 19s - loss: 6.9006 - mean_squared_error: 6.9006 - val_loss: 6.8531 - val_mean_squared_error: 6.8531 - 19s/epoch - 139ms/step
# Epoch 16/200
# 135/135 - 19s - loss: 6.9961 - mean_squared_error: 6.9961 - val_loss: 7.3203 - val_mean_squared_error: 7.3203 - 19s/epoch - 140ms/step
# Epoch 17/200
# 135/135 - 19s - loss: 6.9942 - mean_squared_error: 6.9942 - val_loss: 7.0112 - val_mean_squared_error: 7.0112 - 19s/epoch - 142ms/step
# Epoch 18/200
# 135/135 - 19s - loss: 7.0573 - mean_squared_error: 7.0573 - val_loss: 7.2356 - val_mean_squared_error: 7.2356 - 19s/epoch - 139ms/step
# Epoch 19/200
# 135/135 - 19s - loss: 7.1389 - mean_squared_error: 7.1389 - val_loss: 6.8616 - val_mean_squared_error: 6.8616 - 19s/epoch - 140ms/step
# Epoch 20/200
# 135/135 - 19s - loss: 6.9859 - mean_squared_error: 6.9859 - val_loss: 7.3133 - val_mean_squared_error: 7.3133 - 19s/epoch - 140ms/step
# Epoch 21/200
# 135/135 - 19s - loss: 7.1462 - mean_squared_error: 7.1462 - val_loss: 7.0032 - val_mean_squared_error: 7.0032 - 19s/epoch - 139ms/step
# Epoch 22/200
# 135/135 - 19s - loss: 7.2235 - mean_squared_error: 7.2235 - val_loss: 7.1606 - val_mean_squared_error: 7.1606 - 19s/epoch - 139ms/step
# Epoch 23/200
# 135/135 - 19s - loss: 7.0104 - mean_squared_error: 7.0104 - val_loss: 7.6736 - val_mean_squared_error: 7.6736 - 19s/epoch - 140ms/step
# Epoch 24/200
# 135/135 - 19s - loss: 6.9787 - mean_squared_error: 6.9787 - val_loss: 6.8290 - val_mean_squared_error: 6.8290 - 19s/epoch - 139ms/step
# Epoch 25/200
# 135/135 - 19s - loss: 6.9957 - mean_squared_error: 6.9957 - val_loss: 7.5364 - val_mean_squared_error: 7.5364 - 19s/epoch - 139ms/step
# Epoch 26/200
# 135/135 - 19s - loss: 7.3796 - mean_squared_error: 7.3796 - val_loss: 7.3371 - val_mean_squared_error: 7.3371 - 19s/epoch - 141ms/step
# Epoch 27/200
# 135/135 - 19s - loss: 7.5871 - mean_squared_error: 7.5871 - val_loss: 7.1148 - val_mean_squared_error: 7.1148 - 19s/epoch - 139ms/step
# Epoch 28/200
# 135/135 - 19s - loss: 7.1094 - mean_squared_error: 7.1094 - val_loss: 7.7110 - val_mean_squared_error: 7.7110 - 19s/epoch - 138ms/step
# Epoch 29/200
# 135/135 - 19s - loss: 6.9702 - mean_squared_error: 6.9702 - val_loss: 6.9753 - val_mean_squared_error: 6.9753 - 19s/epoch - 139ms/step
# Epoch 30/200
# 135/135 - 19s - loss: 7.1291 - mean_squared_error: 7.1291 - val_loss: 6.7730 - val_mean_squared_error: 6.7730 - 19s/epoch - 140ms/step
# Epoch 31/200
# 135/135 - 19s - loss: 7.0117 - mean_squared_error: 7.0117 - val_loss: 6.9538 - val_mean_squared_error: 6.9538 - 19s/epoch - 139ms/step
# Epoch 32/200
# 135/135 - 19s - loss: 7.1956 - mean_squared_error: 7.1956 - val_loss: 6.7522 - val_mean_squared_error: 6.7522 - 19s/epoch - 140ms/step
# Epoch 33/200
# 135/135 - 19s - loss: 6.9427 - mean_squared_error: 6.9427 - val_loss: 7.3277 - val_mean_squared_error: 7.3277 - 19s/epoch - 139ms/step
# Epoch 34/200
# 135/135 - 19s - loss: 6.9394 - mean_squared_error: 6.9394 - val_loss: 6.8382 - val_mean_squared_error: 6.8382 - 19s/epoch - 141ms/step
# Epoch 35/200
# 135/135 - 19s - loss: 7.0533 - mean_squared_error: 7.0533 - val_loss: 7.2551 - val_mean_squared_error: 7.2551 - 19s/epoch - 140ms/step
# Epoch 36/200
# 135/135 - 19s - loss: 6.9694 - mean_squared_error: 6.9694 - val_loss: 6.7064 - val_mean_squared_error: 6.7064 - 19s/epoch - 139ms/step
# Epoch 37/200
# 135/135 - 19s - loss: 7.0503 - mean_squared_error: 7.0503 - val_loss: 6.7529 - val_mean_squared_error: 6.7529 - 19s/epoch - 140ms/step
# Epoch 38/200
# 135/135 - 19s - loss: 6.9015 - mean_squared_error: 6.9015 - val_loss: 6.8668 - val_mean_squared_error: 6.8668 - 19s/epoch - 140ms/step
# Epoch 39/200
# 135/135 - 19s - loss: 6.9650 - mean_squared_error: 6.9650 - val_loss: 6.8837 - val_mean_squared_error: 6.8837 - 19s/epoch - 140ms/step
# Epoch 40/200
# 135/135 - 19s - loss: 7.0590 - mean_squared_error: 7.0590 - val_loss: 6.8162 - val_mean_squared_error: 6.8162 - 19s/epoch - 139ms/step
# Epoch 41/200
# 135/135 - 19s - loss: 7.0333 - mean_squared_error: 7.0333 - val_loss: 6.7661 - val_mean_squared_error: 6.7661 - 19s/epoch - 139ms/step
# Epoch 42/200
# 135/135 - 19s - loss: 7.2345 - mean_squared_error: 7.2345 - val_loss: 6.9432 - val_mean_squared_error: 6.9432 - 19s/epoch - 142ms/step
# Epoch 43/200
# 135/135 - 19s - loss: 6.9633 - mean_squared_error: 6.9633 - val_loss: 6.7200 - val_mean_squared_error: 6.7200 - 19s/epoch - 140ms/step
# Epoch 44/200
# 135/135 - 19s - loss: 6.9701 - mean_squared_error: 6.9701 - val_loss: 7.0609 - val_mean_squared_error: 7.0609 - 19s/epoch - 140ms/step
# Epoch 45/200
# 135/135 - 19s - loss: 6.8656 - mean_squared_error: 6.8656 - val_loss: 7.1655 - val_mean_squared_error: 7.1655 - 19s/epoch - 140ms/step
# Epoch 46/200
# 135/135 - 19s - loss: 6.9012 - mean_squared_error: 6.9012 - val_loss: 7.0277 - val_mean_squared_error: 7.0277 - 19s/epoch - 138ms/step
# Epoch 47/200
# 135/135 - 19s - loss: 6.8755 - mean_squared_error: 6.8755 - val_loss: 6.6903 - val_mean_squared_error: 6.6903 - 19s/epoch - 140ms/step
# Epoch 48/200
# 135/135 - 20s - loss: 6.9496 - mean_squared_error: 6.9496 - val_loss: 7.0432 - val_mean_squared_error: 7.0432 - 20s/epoch - 145ms/step
# Epoch 49/200
# 135/135 - 20s - loss: 6.8827 - mean_squared_error: 6.8827 - val_loss: 7.5744 - val_mean_squared_error: 7.5744 - 20s/epoch - 144ms/step
# Epoch 50/200
# 135/135 - 20s - loss: 7.0473 - mean_squared_error: 7.0473 - val_loss: 7.2016 - val_mean_squared_error: 7.2016 - 20s/epoch - 145ms/step
# Epoch 51/200
# 135/135 - 20s - loss: 6.7420 - mean_squared_error: 6.7420 - val_loss: 6.6942 - val_mean_squared_error: 6.6942 - 20s/epoch - 146ms/step
# Epoch 52/200
# 135/135 - 19s - loss: 6.8091 - mean_squared_error: 6.8091 - val_loss: 6.6392 - val_mean_squared_error: 6.6392 - 19s/epoch - 140ms/step
# Epoch 53/200
# 135/135 - 20s - loss: 6.7865 - mean_squared_error: 6.7865 - val_loss: 7.4212 - val_mean_squared_error: 7.4212 - 20s/epoch - 145ms/step
# Epoch 54/200
# 135/135 - 19s - loss: 6.8488 - mean_squared_error: 6.8488 - val_loss: 6.7785 - val_mean_squared_error: 6.7785 - 19s/epoch - 143ms/step
# Epoch 55/200
# 135/135 - 20s - loss: 6.8460 - mean_squared_error: 6.8460 - val_loss: 8.1631 - val_mean_squared_error: 8.1631 - 20s/epoch - 146ms/step
# Epoch 56/200
# 135/135 - 19s - loss: 6.8853 - mean_squared_error: 6.8853 - val_loss: 6.9677 - val_mean_squared_error: 6.9677 - 19s/epoch - 144ms/step
# Epoch 57/200
# 135/135 - 20s - loss: 6.7596 - mean_squared_error: 6.7596 - val_loss: 6.8340 - val_mean_squared_error: 6.8340 - 20s/epoch - 145ms/step
# Epoch 58/200
# 135/135 - 19s - loss: 7.1103 - mean_squared_error: 7.1103 - val_loss: 7.8483 - val_mean_squared_error: 7.8483 - 19s/epoch - 141ms/step
# Epoch 59/200
# 135/135 - 19s - loss: 7.0021 - mean_squared_error: 7.0021 - val_loss: 7.1321 - val_mean_squared_error: 7.1321 - 19s/epoch - 144ms/step
# Epoch 60/200
# 135/135 - 19s - loss: 7.1081 - mean_squared_error: 7.1081 - val_loss: 6.8804 - val_mean_squared_error: 6.8804 - 19s/epoch - 141ms/step
# Epoch 61/200
# 135/135 - 19s - loss: 7.0696 - mean_squared_error: 7.0696 - val_loss: 6.8719 - val_mean_squared_error: 6.8719 - 19s/epoch - 141ms/step
# Epoch 62/200
# 135/135 - 19s - loss: 6.8708 - mean_squared_error: 6.8708 - val_loss: 7.1570 - val_mean_squared_error: 7.1570 - 19s/epoch - 144ms/step
# Epoch 63/200
# 135/135 - 19s - loss: 6.9177 - mean_squared_error: 6.9177 - val_loss: 8.9546 - val_mean_squared_error: 8.9546 - 19s/epoch - 141ms/step
# Epoch 64/200
# 135/135 - 19s - loss: 7.0402 - mean_squared_error: 7.0402 - val_loss: 6.7389 - val_mean_squared_error: 6.7389 - 19s/epoch - 143ms/step
# Epoch 65/200
# 135/135 - 19s - loss: 7.0387 - mean_squared_error: 7.0387 - val_loss: 7.0214 - val_mean_squared_error: 7.0214 - 19s/epoch - 142ms/step
# Epoch 66/200
# 135/135 - 19s - loss: 6.9391 - mean_squared_error: 6.9391 - val_loss: 6.9363 - val_mean_squared_error: 6.9363 - 19s/epoch - 143ms/step
# Epoch 67/200
# 135/135 - 19s - loss: 6.8213 - mean_squared_error: 6.8213 - val_loss: 6.8892 - val_mean_squared_error: 6.8892 - 19s/epoch - 142ms/step
# Epoch 68/200
# 135/135 - 19s - loss: 6.9154 - mean_squared_error: 6.9154 - val_loss: 6.8391 - val_mean_squared_error: 6.8391 - 19s/epoch - 140ms/step
# Epoch 69/200
# 135/135 - 19s - loss: 6.9145 - mean_squared_error: 6.9145 - val_loss: 6.8992 - val_mean_squared_error: 6.8992 - 19s/epoch - 141ms/step
# Epoch 70/200
# 135/135 - 19s - loss: 6.9867 - mean_squared_error: 6.9867 - val_loss: 6.8632 - val_mean_squared_error: 6.8632 - 19s/epoch - 142ms/step
# Epoch 71/200
# 135/135 - 19s - loss: 7.1116 - mean_squared_error: 7.1116 - val_loss: 6.8199 - val_mean_squared_error: 6.8199 - 19s/epoch - 142ms/step
# Epoch 72/200
# 135/135 - 19s - loss: 6.9481 - mean_squared_error: 6.9481 - val_loss: 6.7763 - val_mean_squared_error: 6.7763 - 19s/epoch - 142ms/step
# Epoch 73/200
# 135/135 - 19s - loss: 7.1154 - mean_squared_error: 7.1154 - val_loss: 7.0923 - val_mean_squared_error: 7.0923 - 19s/epoch - 141ms/step
# Epoch 74/200
# 135/135 - 19s - loss: 6.8636 - mean_squared_error: 6.8636 - val_loss: 7.3001 - val_mean_squared_error: 7.3001 - 19s/epoch - 142ms/step
# Epoch 75/200
# 135/135 - 20s - loss: 6.9316 - mean_squared_error: 6.9316 - val_loss: 6.7416 - val_mean_squared_error: 6.7416 - 20s/epoch - 145ms/step
# Epoch 76/200
# 135/135 - 19s - loss: 6.8577 - mean_squared_error: 6.8577 - val_loss: 7.1083 - val_mean_squared_error: 7.1083 - 19s/epoch - 140ms/step
# Epoch 77/200
# 135/135 - 19s - loss: 6.9164 - mean_squared_error: 6.9164 - val_loss: 6.7812 - val_mean_squared_error: 6.7812 - 19s/epoch - 140ms/step
# Epoch 78/200
# 135/135 - 19s - loss: 6.9314 - mean_squared_error: 6.9314 - val_loss: 6.8098 - val_mean_squared_error: 6.8098 - 19s/epoch - 141ms/step
# Epoch 79/200
# 135/135 - 20s - loss: 6.9164 - mean_squared_error: 6.9164 - val_loss: 6.9706 - val_mean_squared_error: 6.9706 - 20s/epoch - 145ms/step
# Epoch 80/200
# 135/135 - 20s - loss: 6.9891 - mean_squared_error: 6.9891 - val_loss: 6.7398 - val_mean_squared_error: 6.7398 - 20s/epoch - 147ms/step
# Epoch 81/200
# 135/135 - 20s - loss: 6.8525 - mean_squared_error: 6.8525 - val_loss: 7.1341 - val_mean_squared_error: 7.1341 - 20s/epoch - 149ms/step
# Epoch 82/200
# 135/135 - 19s - loss: 6.9805 - mean_squared_error: 6.9805 - val_loss: 6.7725 - val_mean_squared_error: 6.7725 - 19s/epoch - 144ms/step
# Epoch 83/200
# 135/135 - 19s - loss: 6.7892 - mean_squared_error: 6.7892 - val_loss: 7.2580 - val_mean_squared_error: 7.2580 - 19s/epoch - 141ms/step
# Epoch 84/200
# 135/135 - 19s - loss: 6.9213 - mean_squared_error: 6.9213 - val_loss: 7.5966 - val_mean_squared_error: 7.5966 - 19s/epoch - 143ms/step
# Epoch 85/200
# 135/135 - 19s - loss: 7.0594 - mean_squared_error: 7.0594 - val_loss: 6.9368 - val_mean_squared_error: 6.9368 - 19s/epoch - 140ms/step
# Epoch 86/200
# 135/135 - 19s - loss: 6.8627 - mean_squared_error: 6.8627 - val_loss: 7.0531 - val_mean_squared_error: 7.0531 - 19s/epoch - 142ms/step
# Epoch 87/200
# 135/135 - 19s - loss: 6.9866 - mean_squared_error: 6.9866 - val_loss: 7.3107 - val_mean_squared_error: 7.3107 - 19s/epoch - 140ms/step
# Epoch 88/200
# 135/135 - 19s - loss: 6.8888 - mean_squared_error: 6.8888 - val_loss: 8.1613 - val_mean_squared_error: 8.1613 - 19s/epoch - 140ms/step
# Epoch 89/200
# 135/135 - 19s - loss: 6.8216 - mean_squared_error: 6.8216 - val_loss: 6.7718 - val_mean_squared_error: 6.7718 - 19s/epoch - 139ms/step
# Epoch 90/200
# 135/135 - 19s - loss: 6.8086 - mean_squared_error: 6.8086 - val_loss: 6.7415 - val_mean_squared_error: 6.7415 - 19s/epoch - 139ms/step
# Epoch 91/200
# 135/135 - 19s - loss: 6.8274 - mean_squared_error: 6.8274 - val_loss: 6.8792 - val_mean_squared_error: 6.8792 - 19s/epoch - 140ms/step
# Epoch 92/200
# 135/135 - 19s - loss: 6.8293 - mean_squared_error: 6.8293 - val_loss: 6.7039 - val_mean_squared_error: 6.7039 - 19s/epoch - 139ms/step
# Epoch 93/200
# 135/135 - 19s - loss: 6.8241 - mean_squared_error: 6.8241 - val_loss: 6.8268 - val_mean_squared_error: 6.8268 - 19s/epoch - 142ms/step
# Epoch 94/200
# 135/135 - 19s - loss: 6.8556 - mean_squared_error: 6.8556 - val_loss: 6.7150 - val_mean_squared_error: 6.7150 - 19s/epoch - 143ms/step
# Epoch 95/200
# 135/135 - 19s - loss: 6.8335 - mean_squared_error: 6.8335 - val_loss: 6.6837 - val_mean_squared_error: 6.6837 - 19s/epoch - 143ms/step
# Epoch 96/200
# 135/135 - 19s - loss: 6.8052 - mean_squared_error: 6.8052 - val_loss: 6.7474 - val_mean_squared_error: 6.7474 - 19s/epoch - 143ms/step
# Epoch 97/200
# 135/135 - 19s - loss: 6.8001 - mean_squared_error: 6.8001 - val_loss: 6.9276 - val_mean_squared_error: 6.9276 - 19s/epoch - 144ms/step
# Epoch 98/200
# 135/135 - 19s - loss: 6.9484 - mean_squared_error: 6.9484 - val_loss: 6.7318 - val_mean_squared_error: 6.7318 - 19s/epoch - 139ms/step
# Epoch 99/200
# 135/135 - 19s - loss: 6.7761 - mean_squared_error: 6.7761 - val_loss: 6.9125 - val_mean_squared_error: 6.9125 - 19s/epoch - 141ms/step
# Epoch 100/200
# 135/135 - 19s - loss: 6.8168 - mean_squared_error: 6.8168 - val_loss: 6.6734 - val_mean_squared_error: 6.6734 - 19s/epoch - 143ms/step
# Epoch 101/200
# 135/135 - 19s - loss: 6.9415 - mean_squared_error: 6.9415 - val_loss: 6.7536 - val_mean_squared_error: 6.7536 - 19s/epoch - 140ms/step
# Epoch 102/200
# 135/135 - 19s - loss: 6.9642 - mean_squared_error: 6.9642 - val_loss: 6.7425 - val_mean_squared_error: 6.7425 - 19s/epoch - 140ms/step
# Epoch 103/200
# 135/135 - 19s - loss: 6.7411 - mean_squared_error: 6.7411 - val_loss: 6.8285 - val_mean_squared_error: 6.8285 - 19s/epoch - 139ms/step
# Epoch 104/200
# 135/135 - 19s - loss: 6.6898 - mean_squared_error: 6.6898 - val_loss: 6.7518 - val_mean_squared_error: 6.7518 - 19s/epoch - 144ms/step
# Epoch 105/200
# 135/135 - 19s - loss: 6.6877 - mean_squared_error: 6.6877 - val_loss: 6.6820 - val_mean_squared_error: 6.6820 - 19s/epoch - 139ms/step
# Epoch 106/200
# 135/135 - 19s - loss: 6.8763 - mean_squared_error: 6.8763 - val_loss: 6.6567 - val_mean_squared_error: 6.6567 - 19s/epoch - 138ms/step
# Epoch 107/200
# 135/135 - 19s - loss: 6.7410 - mean_squared_error: 6.7410 - val_loss: 7.2612 - val_mean_squared_error: 7.2612 - 19s/epoch - 143ms/step
# Epoch 108/200
# 135/135 - 19s - loss: 6.7406 - mean_squared_error: 6.7406 - val_loss: 6.6493 - val_mean_squared_error: 6.6493 - 19s/epoch - 141ms/step
# Epoch 109/200
# 135/135 - 19s - loss: 6.8963 - mean_squared_error: 6.8963 - val_loss: 10.2616 - val_mean_squared_error: 10.2616 - 19s/epoch - 143ms/step
# Epoch 110/200
# 135/135 - 19s - loss: 6.8550 - mean_squared_error: 6.8550 - val_loss: 6.7189 - val_mean_squared_error: 6.7189 - 19s/epoch - 144ms/step
# Epoch 111/200
# 135/135 - 19s - loss: 6.7734 - mean_squared_error: 6.7734 - val_loss: 7.1745 - val_mean_squared_error: 7.1745 - 19s/epoch - 143ms/step
# Epoch 112/200
# 135/135 - 20s - loss: 6.8901 - mean_squared_error: 6.8901 - val_loss: 6.8247 - val_mean_squared_error: 6.8247 - 20s/epoch - 147ms/step
# Epoch 113/200
# 135/135 - 19s - loss: 6.6805 - mean_squared_error: 6.6805 - val_loss: 6.7906 - val_mean_squared_error: 6.7906 - 19s/epoch - 144ms/step
# Epoch 114/200
# 135/135 - 19s - loss: 6.7208 - mean_squared_error: 6.7208 - val_loss: 6.7744 - val_mean_squared_error: 6.7744 - 19s/epoch - 139ms/step
# Epoch 115/200
# 135/135 - 19s - loss: 6.6732 - mean_squared_error: 6.6732 - val_loss: 6.6970 - val_mean_squared_error: 6.6970 - 19s/epoch - 142ms/step
# Epoch 116/200
# 135/135 - 19s - loss: 6.6305 - mean_squared_error: 6.6305 - val_loss: 6.6315 - val_mean_squared_error: 6.6315 - 19s/epoch - 140ms/step
# Epoch 117/200
# 135/135 - 19s - loss: 6.7521 - mean_squared_error: 6.7521 - val_loss: 6.7386 - val_mean_squared_error: 6.7386 - 19s/epoch - 144ms/step
# Epoch 118/200
# 135/135 - 19s - loss: 6.8393 - mean_squared_error: 6.8393 - val_loss: 6.6672 - val_mean_squared_error: 6.6672 - 19s/epoch - 141ms/step
# Epoch 119/200
# 135/135 - 19s - loss: 6.5843 - mean_squared_error: 6.5843 - val_loss: 6.5886 - val_mean_squared_error: 6.5886 - 19s/epoch - 140ms/step
# Epoch 120/200
# 135/135 - 19s - loss: 6.9182 - mean_squared_error: 6.9182 - val_loss: 6.9985 - val_mean_squared_error: 6.9985 - 19s/epoch - 143ms/step
# Epoch 121/200
# 135/135 - 20s - loss: 6.6540 - mean_squared_error: 6.6540 - val_loss: 6.6778 - val_mean_squared_error: 6.6778 - 20s/epoch - 146ms/step
# Epoch 122/200
# 135/135 - 19s - loss: 6.6406 - mean_squared_error: 6.6406 - val_loss: 6.6128 - val_mean_squared_error: 6.6128 - 19s/epoch - 144ms/step
# Epoch 123/200
# 135/135 - 19s - loss: 6.6040 - mean_squared_error: 6.6040 - val_loss: 6.6167 - val_mean_squared_error: 6.6167 - 19s/epoch - 139ms/step
# Epoch 124/200
# 135/135 - 19s - loss: 6.7926 - mean_squared_error: 6.7926 - val_loss: 6.7584 - val_mean_squared_error: 6.7584 - 19s/epoch - 139ms/step
# Epoch 125/200
# 135/135 - 19s - loss: 6.6686 - mean_squared_error: 6.6686 - val_loss: 7.5072 - val_mean_squared_error: 7.5072 - 19s/epoch - 144ms/step
# Epoch 126/200
# 135/135 - 19s - loss: 6.5872 - mean_squared_error: 6.5872 - val_loss: 6.5837 - val_mean_squared_error: 6.5837 - 19s/epoch - 140ms/step
# Epoch 127/200
# 135/135 - 19s - loss: 6.5853 - mean_squared_error: 6.5853 - val_loss: 6.5184 - val_mean_squared_error: 6.5184 - 19s/epoch - 141ms/step
# Epoch 128/200
# 135/135 - 19s - loss: 6.4883 - mean_squared_error: 6.4883 - val_loss: 6.5493 - val_mean_squared_error: 6.5493 - 19s/epoch - 139ms/step
# Epoch 129/200
# 135/135 - 19s - loss: 6.7424 - mean_squared_error: 6.7424 - val_loss: 7.0543 - val_mean_squared_error: 7.0543 - 19s/epoch - 144ms/step
# Epoch 130/200
# 135/135 - 19s - loss: 6.5916 - mean_squared_error: 6.5916 - val_loss: 7.1344 - val_mean_squared_error: 7.1344 - 19s/epoch - 143ms/step
# Epoch 131/200
# 135/135 - 19s - loss: 6.4827 - mean_squared_error: 6.4827 - val_loss: 7.6740 - val_mean_squared_error: 7.6740 - 19s/epoch - 141ms/step
# Epoch 132/200
# 135/135 - 20s - loss: 6.4706 - mean_squared_error: 6.4706 - val_loss: 7.0262 - val_mean_squared_error: 7.0262 - 20s/epoch - 147ms/step
# Epoch 133/200
# 135/135 - 19s - loss: 6.5207 - mean_squared_error: 6.5207 - val_loss: 6.4095 - val_mean_squared_error: 6.4095 - 19s/epoch - 141ms/step
# Epoch 134/200
# 135/135 - 19s - loss: 6.4067 - mean_squared_error: 6.4067 - val_loss: 6.4884 - val_mean_squared_error: 6.4884 - 19s/epoch - 142ms/step
# Epoch 135/200
# 135/135 - 19s - loss: 6.2833 - mean_squared_error: 6.2833 - val_loss: 6.4910 - val_mean_squared_error: 6.4910 - 19s/epoch - 144ms/step
# Epoch 136/200
# 135/135 - 21s - loss: 6.4201 - mean_squared_error: 6.4201 - val_loss: 6.1214 - val_mean_squared_error: 6.1214 - 21s/epoch - 156ms/step
# Epoch 137/200
# 135/135 - 19s - loss: 6.0276 - mean_squared_error: 6.0276 - val_loss: 6.6905 - val_mean_squared_error: 6.6905 - 19s/epoch - 139ms/step
# Epoch 138/200
# 135/135 - 19s - loss: 5.9654 - mean_squared_error: 5.9654 - val_loss: 5.9590 - val_mean_squared_error: 5.9590 - 19s/epoch - 141ms/step
# Epoch 139/200
# 135/135 - 19s - loss: 5.9192 - mean_squared_error: 5.9192 - val_loss: 6.0104 - val_mean_squared_error: 6.0104 - 19s/epoch - 143ms/step
# Epoch 140/200
# 135/135 - 19s - loss: 5.8515 - mean_squared_error: 5.8515 - val_loss: 6.4831 - val_mean_squared_error: 6.4831 - 19s/epoch - 141ms/step
# Epoch 141/200
# 135/135 - 20s - loss: 5.8422 - mean_squared_error: 5.8422 - val_loss: 6.1483 - val_mean_squared_error: 6.1483 - 20s/epoch - 145ms/step
# Epoch 142/200
# 135/135 - 19s - loss: 5.8463 - mean_squared_error: 5.8463 - val_loss: 6.4215 - val_mean_squared_error: 6.4215 - 19s/epoch - 140ms/step
# Epoch 143/200
# 135/135 - 19s - loss: 5.6787 - mean_squared_error: 5.6787 - val_loss: 5.6858 - val_mean_squared_error: 5.6858 - 19s/epoch - 143ms/step
# Epoch 144/200
# 135/135 - 19s - loss: 5.5239 - mean_squared_error: 5.5239 - val_loss: 5.5817 - val_mean_squared_error: 5.5817 - 19s/epoch - 140ms/step
# Epoch 145/200
# 135/135 - 20s - loss: 5.6925 - mean_squared_error: 5.6925 - val_loss: 8.2737 - val_mean_squared_error: 8.2737 - 20s/epoch - 145ms/step
# Epoch 146/200
# 135/135 - 19s - loss: 5.6374 - mean_squared_error: 5.6374 - val_loss: 5.5749 - val_mean_squared_error: 5.5749 - 19s/epoch - 140ms/step
# Epoch 147/200
# 135/135 - 19s - loss: 5.4956 - mean_squared_error: 5.4956 - val_loss: 6.2370 - val_mean_squared_error: 6.2370 - 19s/epoch - 141ms/step
# Epoch 148/200
# 135/135 - 19s - loss: 5.4583 - mean_squared_error: 5.4583 - val_loss: 5.6465 - val_mean_squared_error: 5.6465 - 19s/epoch - 143ms/step
# Epoch 149/200
# 135/135 - 20s - loss: 5.5327 - mean_squared_error: 5.5327 - val_loss: 5.9672 - val_mean_squared_error: 5.9672 - 20s/epoch - 146ms/step
# Epoch 150/200
# 135/135 - 20s - loss: 5.4826 - mean_squared_error: 5.4826 - val_loss: 5.4678 - val_mean_squared_error: 5.4678 - 20s/epoch - 144ms/step
# Epoch 151/200
# 135/135 - 20s - loss: 5.4232 - mean_squared_error: 5.4232 - val_loss: 5.5912 - val_mean_squared_error: 5.5912 - 20s/epoch - 147ms/step
# Epoch 152/200
# 135/135 - 19s - loss: 5.5369 - mean_squared_error: 5.5369 - val_loss: 5.6027 - val_mean_squared_error: 5.6027 - 19s/epoch - 139ms/step
# Epoch 153/200
# 135/135 - 19s - loss: 5.3697 - mean_squared_error: 5.3697 - val_loss: 7.4497 - val_mean_squared_error: 7.4497 - 19s/epoch - 140ms/step
# Epoch 154/200
# 135/135 - 20s - loss: 5.3250 - mean_squared_error: 5.3250 - val_loss: 5.4284 - val_mean_squared_error: 5.4284 - 20s/epoch - 145ms/step
# Epoch 155/200
# 135/135 - 19s - loss: 5.2895 - mean_squared_error: 5.2895 - val_loss: 5.7345 - val_mean_squared_error: 5.7345 - 19s/epoch - 141ms/step
# Epoch 156/200
# 135/135 - 19s - loss: 5.4506 - mean_squared_error: 5.4506 - val_loss: 5.8331 - val_mean_squared_error: 5.8331 - 19s/epoch - 144ms/step
# Epoch 157/200
# 135/135 - 20s - loss: 5.3327 - mean_squared_error: 5.3327 - val_loss: 5.4826 - val_mean_squared_error: 5.4826 - 20s/epoch - 149ms/step
# Epoch 158/200
# 135/135 - 19s - loss: 5.2205 - mean_squared_error: 5.2205 - val_loss: 6.0271 - val_mean_squared_error: 6.0271 - 19s/epoch - 141ms/step
# Epoch 159/200
# 135/135 - 19s - loss: 5.2399 - mean_squared_error: 5.2399 - val_loss: 5.6529 - val_mean_squared_error: 5.6529 - 19s/epoch - 139ms/step
# Epoch 160/200
# 135/135 - 19s - loss: 5.2411 - mean_squared_error: 5.2411 - val_loss: 5.7077 - val_mean_squared_error: 5.7077 - 19s/epoch - 141ms/step
# Epoch 161/200
# 135/135 - 19s - loss: 5.2278 - mean_squared_error: 5.2278 - val_loss: 5.6862 - val_mean_squared_error: 5.6862 - 19s/epoch - 143ms/step
# Epoch 162/200
# 135/135 - 19s - loss: 5.1976 - mean_squared_error: 5.1976 - val_loss: 5.9083 - val_mean_squared_error: 5.9083 - 19s/epoch - 141ms/step
# Epoch 163/200
# 135/135 - 19s - loss: 5.1992 - mean_squared_error: 5.1992 - val_loss: 6.6031 - val_mean_squared_error: 6.6031 - 19s/epoch - 139ms/step
# Epoch 164/200
# 135/135 - 19s - loss: 5.0752 - mean_squared_error: 5.0752 - val_loss: 5.2420 - val_mean_squared_error: 5.2420 - 19s/epoch - 142ms/step
# Epoch 165/200
# 135/135 - 19s - loss: 5.1109 - mean_squared_error: 5.1109 - val_loss: 5.2425 - val_mean_squared_error: 5.2425 - 19s/epoch - 140ms/step
# Epoch 166/200
# 135/135 - 19s - loss: 5.1923 - mean_squared_error: 5.1923 - val_loss: 5.4091 - val_mean_squared_error: 5.4091 - 19s/epoch - 142ms/step
# Epoch 167/200
# 135/135 - 19s - loss: 5.0863 - mean_squared_error: 5.0863 - val_loss: 5.2059 - val_mean_squared_error: 5.2059 - 19s/epoch - 141ms/step
# Epoch 168/200
# 135/135 - 20s - loss: 5.0240 - mean_squared_error: 5.0240 - val_loss: 5.2168 - val_mean_squared_error: 5.2168 - 20s/epoch - 147ms/step
# Epoch 169/200
# 135/135 - 19s - loss: 5.0649 - mean_squared_error: 5.0649 - val_loss: 5.3809 - val_mean_squared_error: 5.3809 - 19s/epoch - 143ms/step
# Epoch 170/200
# 135/135 - 19s - loss: 5.0035 - mean_squared_error: 5.0035 - val_loss: 5.3698 - val_mean_squared_error: 5.3698 - 19s/epoch - 142ms/step
# Epoch 171/200
# 135/135 - 19s - loss: 4.9649 - mean_squared_error: 4.9649 - val_loss: 5.4317 - val_mean_squared_error: 5.4317 - 19s/epoch - 144ms/step
# Epoch 172/200
# 135/135 - 19s - loss: 4.9577 - mean_squared_error: 4.9577 - val_loss: 5.1360 - val_mean_squared_error: 5.1360 - 19s/epoch - 140ms/step
# Epoch 173/200
# 135/135 - 19s - loss: 5.0461 - mean_squared_error: 5.0461 - val_loss: 5.4144 - val_mean_squared_error: 5.4144 - 19s/epoch - 140ms/step
# Epoch 174/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kmoy14/Documents/CS 230/cs-230-final-project/CNN_MSE.ipynb Cell 7' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000006?line=0'>1</a> history = cnn_model.fit(X_train,
#       <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000006?line=1'>2</a>                     y_train,
#       <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000006?line=2'>3</a>                     epochs=200,
#       <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000006?line=3'>4</a>                     verbose=2,
#       <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000006?line=4'>5</a>                     batch_size=480,
#       <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000006?line=5'>6</a>                     validation_split=0.2)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1401'>1402</a> with tf.profiler.experimental.Trace(
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1402'>1403</a>     'train',
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1403'>1404</a>     epoch_num=epoch,
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1404'>1405</a>     step_num=step,
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1405'>1406</a>     batch_size=batch_size,
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1406'>1407</a>     _r=1):
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1407'>1408</a>   callbacks.on_train_batch_begin(step)
# -> <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1408'>1409</a>   tmp_logs = self.train_function(iterator)
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1409'>1410</a>   if data_handler.should_sync:
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py?line=1410'>1411</a>     context.async_wait()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=911'>912</a> compiler = "xla" if self._jit_compile else "nonXla"
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=913'>914</a> with OptionalXlaContext(self._jit_compile):
# --> <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=914'>915</a>   result = self._call(*args, **kwds)
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=916'>917</a> new_tracing_count = self.experimental_get_tracing_count()
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=917'>918</a> without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=943'>944</a>   self._lock.release()
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=944'>945</a>   # In this case we have created variables on the first call, so we run the
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=945'>946</a>   # defunned version which is guaranteed to never create variables.
# --> <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=946'>947</a>   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=947'>948</a> elif self._stateful_fn is not None:
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=948'>949</a>   # Release the lock early so that multiple threads can perform the call
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=949'>950</a>   # in parallel.
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py?line=950'>951</a>   self._lock.release()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2449'>2450</a> with self._lock:
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2450'>2451</a>   (graph_function,
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2451'>2452</a>    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2452'>2453</a> return graph_function._call_flat(
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=2453'>2454</a>     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1855'>1856</a> possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1856'>1857</a> if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1857'>1858</a>     and executing_eagerly):
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1858'>1859</a>   # No tape is watching; skip to running the function.
# -> <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1859'>1860</a>   return self._build_call_outputs(self._inference_function.call(
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1860'>1861</a>       ctx, args, cancellation_manager=cancellation_manager))
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1861'>1862</a> forward_backward = self._select_forward_and_backward_functions(
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1862'>1863</a>     args,
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1863'>1864</a>     possible_gradient_type,
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1864'>1865</a>     executing_eagerly)
#    <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=1865'>1866</a> forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=494'>495</a> with _InterpolateFunctionError(self):
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=495'>496</a>   if cancellation_manager is None:
# --> <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=496'>497</a>     outputs = execute.execute(
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=497'>498</a>         str(self.signature.name),
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=498'>499</a>         num_outputs=self._num_outputs,
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=499'>500</a>         inputs=args,
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=500'>501</a>         attrs=attrs,
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=501'>502</a>         ctx=ctx)
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=502'>503</a>   else:
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=503'>504</a>     outputs = execute.execute_with_cancellation(
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=504'>505</a>         str(self.signature.name),
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=505'>506</a>         num_outputs=self._num_outputs,
#    (...)
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=508'>509</a>         ctx=ctx,
#     <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/function.py?line=509'>510</a>         cancellation_manager=cancellation_manager)
#
# File ~/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=51'>52</a> try:
#      <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=52'>53</a>   ctx.ensure_initialized()
# ---> <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=53'>54</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=54'>55</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> except core._NotOkStatusException as e:
#      <a href='file:///Users/kmoy14/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   if name is not None:
#
# KeyboardInterrupt:

# %%
cnn_model.save("cnnmodel_w8_200_MSE")

# %%
y_hat = cnn_model.predict(X_test)
y_hat_plot = np.ravel(y_hat)
plt.plot(y_hat_plot)
plt.plot(y_test, linewidth=3)
plt.legend(['Estimated W9', 'Actual W9'])
plt.xlabel("Datapoint [-]")
plt.ylabel("Capacity [%]")
plt.show()
cnn_model.evaluate(X_test, y_test, verbose=2)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.xlabel("Epoch [-]")
plt.ylabel("Loss [%]")
plt.show()
# Out:
#  18/223 [=>............................] - ETA: 1s
# 2022-05-22 23:39:11.168198: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 223/223 [==============================] - 1s 6ms/step
# 223/223 - 1s - loss: 5.0313 - mean_squared_error: 5.0313 - 1s/epoch - 7ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kmoy14/Documents/CS 230/cs-230-final-project/CNN_MSE.ipynb Cell 9' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000008?line=7'>8</a> plt.show()
#       <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000008?line=8'>9</a> cnn_model.evaluate(X_test, y_test, verbose=2)
# ---> <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000008?line=10'>11</a> plt.plot(history.history['loss'])
#      <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000008?line=11'>12</a> plt.plot(history.history['val_loss'])
#      <a href='vscode-notebook-cell:/Users/kmoy14/Documents/CS%20230/cs-230-final-project/CNN_MSE.ipynb#ch0000008?line=12'>13</a> plt.legend(['Training', 'Validation'])
#
# NameError: name 'history' is not defined
