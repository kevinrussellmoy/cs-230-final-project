# %% [markdown]
# # Multi-headed CNN model
# see: https://machinelearningmastery.com/how-to-develop-convolutional-neural-network-models-for-time-series-forecasting/

# %%
# Import statements
import tensorflow as tf
import numpy as np
import scipy.io
import os
import matplotlib.pyplot as plt
import h5py
import pandas as pd

from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle

# Plot formatting defaults
plt.rc('ytick', direction='out')
plt.rc('grid', color='w', linestyle='solid')
plt.rcParams['figure.figsize'] = [10, 8]
plt.rcParams.update({'font.size': 22})
plt.rc('xtick', direction='out')
plt.rc('patch', edgecolor='#E6E6E6')
plt.rc('lines', linewidth=2)

# %%
# Load in train and test data

mat = scipy.io.loadmat('W8_samples.mat')
W8_cell_data = mat['cell_data']

mat = scipy.io.loadmat('W9_samples.mat')
W9_cell_data = mat['cell_data']

mat = scipy.io.loadmat('W10_samples.mat')
W10_cell_data = mat['cell_data']

mat = scipy.io.loadmat('W5_samples.mat')
W5_cell_data = mat['cell_data']

del mat

X_train, y_train = shuffle(W8_cell_data[:,1:], W8_cell_data[:,0])

X_test = W9_cell_data[:,1:]
y_test = W9_cell_data[:,0]

# Reshape for CNN: shape = (# samples, # timesteps, # features)
X_train = np.transpose(np.reshape(X_train, (X_train.shape[0], 2, int(X_train.shape[1]/2))), (0, 2, 1))
X_test = np.transpose(np.reshape(X_test, (X_test.shape[0], 2, int(X_test.shape[1]/2))), (0, 2, 1))

# Split into two vectors: one for voltage, one for current
X_trainVolts = X_train[:,:,0]
X_trainAmps = X_train[:,:,1]
X_testVolts = X_test[:,:,0]
X_testAmps = X_test[:,:,1]

# Split off and reserve dev set from train set
X_trainVolts, X_devVolts, X_trainAmps, X_devAmps, y_train, y_dev = train_test_split(X_trainVolts, X_trainAmps, y_train, test_size=0.1, shuffle= True)

# Save dimensions for LSTM
n_feat = X_train.shape[1]

#W10 cell data
X_test_W10 = W10_cell_data[:,1:]
y_test_W10 = W10_cell_data[:,0]

# Reshape for CNN: shape = (# samples, # timesteps, # features)
X_test_W10 = np.transpose(np.reshape(X_test_W10, (X_test_W10.shape[0], 2, int(X_test_W10.shape[1]/2))), (0, 2, 1))

X_testVolts_W10 = X_test_W10[:,:,0]
X_testAmps_W10 = X_test_W10[:,:,1]

#W5 cell data
X_test_W5 = W5_cell_data[:,1:]
y_test_W5 = W5_cell_data[:,0]

# Reshape for CNN: shape = (# samples, # timesteps, # features)
X_test_W5 = np.transpose(np.reshape(X_test_W5, (X_test_W5.shape[0], 2, int(X_test_W5.shape[1]/2))), (0, 2, 1))

X_testVolts_W5 = X_test_W5[:,:,0]
X_testAmps_W5 = X_test_W5[:,:,1]

print(X_trainVolts.shape)
print(X_trainAmps.shape)
# Out:
# (72811, 1200)
# (72811, 1200)

# %%
# Rescale output to min 0, max 1:
min_max_scaler = MinMaxScaler().fit(np.concatenate((y_train, y_test, y_dev, y_test_W10, y_test_W5)).reshape((-1,1)))

y_train_scaled = min_max_scaler.transform(y_train.reshape((-1,1))).reshape(-1,)
y_test_scaled = min_max_scaler.transform(y_test.reshape((-1,1))).reshape(-1,)
y_dev_scaled = min_max_scaler.transform(y_dev.reshape((-1,1))).reshape(-1,)
y_test_W10_scaled = min_max_scaler.transform(y_test_W10.reshape((-1,1))).reshape(-1,)
y_test_W5_scaled = min_max_scaler.transform(y_test_W5.reshape((-1,1))).reshape(-1,)

# %%
print(y_train.shape)
print(y_train_scaled.shape)
# Out:
# (72811,)
# (72811,)

# %%
plt.plot(y_test_W10_scaled)
plt.plot(y_test_W5_scaled)
plt.plot(y_test_scaled)
plt.show()

# %%
# Downsample test by 1/10th
y_test_ds = y_test_scaled[0::10]
X_testVolts_ds= X_testVolts[0::10, :]
X_testAmps_ds= X_testAmps[0::10, :]

y_test_W10_ds = y_test_W10_scaled[0::10]
X_testVolts_W10_ds= X_testVolts_W10[0::10, :]
X_testAmps_W10_ds= X_testAmps_W10[0::10, :]

y_test_W5_ds = y_test_W5_scaled[0::10]
X_testVolts_W5_ds= X_testVolts_W5[0::10, :]
X_testAmps_W5_ds = X_testAmps_W5[0::10, :]

# %%
# Downsample train and dev by 1/10th for testing
X_trainVolts_ds = X_trainVolts[0::10, :]
X_trainAmps_ds = X_trainAmps[0::10, :]
y_train_ds = y_train_scaled[0::10]

X_devVolts_ds = X_devVolts[0::10, :]
X_devAmps_ds = X_devAmps[0::10, :]
y_dev_ds = y_dev_scaled[0::10]

print(X_trainVolts_ds.shape)
print(X_trainAmps_ds.shape)
print(y_train_ds.shape)

print(X_devVolts_ds.shape)
print(X_devAmps_ds.shape)
print(y_dev_ds.shape)
# Out:
# (7282, 1200)
# (7282, 1200)
# (7282,)
# (810, 1200)
# (810, 1200)
# (810,)

# %% [markdown]
# ## Model initialization and fit

# %%
# 1D CNN for current and voltage data
def create_1d_cnn(feat, chan):

    inputShape = (feat, chan,)

    # define the model input
    inputs = layers.Input(shape=inputShape)
 
    x = inputs

    # the first branch operates on the first input
    x = layers.Conv1D(32, 10)(x)
    x = layers.MaxPool1D(pool_size=(4))(x)
    x = layers.Conv1D(16, 5)(x)
    x = layers.MaxPool1D(pool_size=(2))(x)
    x = layers.Conv1D(8, 5)(x)
    x = layers.MaxPool1D(pool_size=(2))(x)
    x = layers.Conv1D(8, 5)(x)
    x = layers.MaxPool1D(pool_size=(2))(x)
    x = layers.Flatten()(x)

    model = tf.keras.models.Model(inputs, x)

    return model

# %%
# create the CNN models for voltage and current
cnnVolts = create_1d_cnn(1200, 1)
cnnAmps = create_1d_cnn(1200, 1)

# create the input to our final set of layers as the *output* of both the CNNs
combinedInput = layers.concatenate([cnnVolts.output, cnnAmps.output])

# our final FC layer head will have two dense layers, the final one
# being our regression head
x = layers.Dense(100, activation="relu")(combinedInput)
x = layers.Dense(1, activation="linear")(x)

model = tf.keras.models.Model(inputs=[cnnVolts.input, cnnAmps.input], outputs=x)

# %%
model.summary()
# Out:
# Model: "model_53"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_39 (InputLayer)          [(None, 1200, 1)]    0           []
#
#  input_40 (InputLayer)          [(None, 1200, 1)]    0           []
#
#  conv1d_102 (Conv1D)            (None, 1191, 32)     352         ['input_39[0][0]']
#
#  conv1d_106 (Conv1D)            (None, 1191, 32)     352         ['input_40[0][0]']
#
#  max_pooling1d_98 (MaxPooling1D  (None, 297, 32)     0           ['conv1d_102[0][0]']
#  )
#
#  max_pooling1d_102 (MaxPooling1  (None, 297, 32)     0           ['conv1d_106[0][0]']
#  D)
#
#  conv1d_103 (Conv1D)            (None, 293, 16)      2576        ['max_pooling1d_98[0][0]']
#
#  conv1d_107 (Conv1D)            (None, 293, 16)      2576        ['max_pooling1d_102[0][0]']
#
#  max_pooling1d_99 (MaxPooling1D  (None, 146, 16)     0           ['conv1d_103[0][0]']
#  )
#
#  max_pooling1d_103 (MaxPooling1  (None, 146, 16)     0           ['conv1d_107[0][0]']
#  D)
#
#  conv1d_104 (Conv1D)            (None, 142, 8)       648         ['max_pooling1d_99[0][0]']
#
#  conv1d_108 (Conv1D)            (None, 142, 8)       648         ['max_pooling1d_103[0][0]']
#
#  max_pooling1d_100 (MaxPooling1  (None, 71, 8)       0           ['conv1d_104[0][0]']
#  D)
#
#  max_pooling1d_104 (MaxPooling1  (None, 71, 8)       0           ['conv1d_108[0][0]']
#  D)
#
#  conv1d_105 (Conv1D)            (None, 67, 8)        328         ['max_pooling1d_100[0][0]']
#
#  conv1d_109 (Conv1D)            (None, 67, 8)        328         ['max_pooling1d_104[0][0]']
#
#  max_pooling1d_101 (MaxPooling1  (None, 33, 8)       0           ['conv1d_105[0][0]']
#  D)
#
#  max_pooling1d_105 (MaxPooling1  (None, 33, 8)       0           ['conv1d_109[0][0]']
#  D)
#
#  flatten_34 (Flatten)           (None, 264)          0           ['max_pooling1d_101[0][0]']
#
#  flatten_35 (Flatten)           (None, 264)          0           ['max_pooling1d_105[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 528)          0           ['flatten_34[0][0]',
#                                                                   'flatten_35[0][0]']
#
#  dense_34 (Dense)               (None, 100)          52900       ['concatenate_17[0][0]']
#
#  dense_35 (Dense)               (None, 1)            101         ['dense_34[0][0]']
#
# ==================================================================================================
# Total params: 60,809
# Trainable params: 60,809
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from datetime import datetime
# Define the Keras TensorBoard callback.
logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(),
    loss="mean_squared_error",
    metrics=["mean_squared_error"],
)

history = model.fit(x=[X_trainVolts, X_trainAmps], y=y_train_scaled,
                    validation_data=([X_devVolts, X_devAmps], y_dev_scaled),
                    epochs=500,
                    verbose=2,
                    batch_size=92)
# Out:
# Epoch 1/500
# 2022-05-25 12:21:39.219271: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-05-25 12:21:54.780406: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 792/792 - 20s - loss: 0.1216 - mean_squared_error: 0.1216 - val_loss: 0.1207 - val_mean_squared_error: 0.1207 - 20s/epoch - 25ms/step
# Epoch 2/500
# 792/792 - 15s - loss: 0.1200 - mean_squared_error: 0.1200 - val_loss: 0.1204 - val_mean_squared_error: 0.1204 - 15s/epoch - 19ms/step
# Epoch 3/500
# 792/792 - 15s - loss: 0.1199 - mean_squared_error: 0.1199 - val_loss: 0.1205 - val_mean_squared_error: 0.1205 - 15s/epoch - 19ms/step
# Epoch 4/500
# 792/792 - 15s - loss: 0.1194 - mean_squared_error: 0.1194 - val_loss: 0.1202 - val_mean_squared_error: 0.1202 - 15s/epoch - 19ms/step
# Epoch 5/500
# 792/792 - 15s - loss: 0.1184 - mean_squared_error: 0.1184 - val_loss: 0.1192 - val_mean_squared_error: 0.1192 - 15s/epoch - 19ms/step
# Epoch 6/500
# 792/792 - 15s - loss: 0.1172 - mean_squared_error: 0.1172 - val_loss: 0.1171 - val_mean_squared_error: 0.1171 - 15s/epoch - 19ms/step
# Epoch 7/500
# 792/792 - 15s - loss: 0.1154 - mean_squared_error: 0.1154 - val_loss: 0.1141 - val_mean_squared_error: 0.1141 - 15s/epoch - 19ms/step
# Epoch 8/500
# 792/792 - 15s - loss: 0.1090 - mean_squared_error: 0.1090 - val_loss: 0.1049 - val_mean_squared_error: 0.1049 - 15s/epoch - 19ms/step
# Epoch 9/500
# 792/792 - 15s - loss: 0.1001 - mean_squared_error: 0.1001 - val_loss: 0.0978 - val_mean_squared_error: 0.0978 - 15s/epoch - 19ms/step
# Epoch 10/500
# 792/792 - 15s - loss: 0.0969 - mean_squared_error: 0.0969 - val_loss: 0.0976 - val_mean_squared_error: 0.0976 - 15s/epoch - 19ms/step
# Epoch 11/500
# 792/792 - 15s - loss: 0.0954 - mean_squared_error: 0.0954 - val_loss: 0.0995 - val_mean_squared_error: 0.0995 - 15s/epoch - 19ms/step
# Epoch 12/500
# 792/792 - 15s - loss: 0.0939 - mean_squared_error: 0.0939 - val_loss: 0.0923 - val_mean_squared_error: 0.0923 - 15s/epoch - 19ms/step
# Epoch 13/500
# 792/792 - 15s - loss: 0.0890 - mean_squared_error: 0.0890 - val_loss: 0.0814 - val_mean_squared_error: 0.0814 - 15s/epoch - 19ms/step
# Epoch 14/500
# 792/792 - 15s - loss: 0.0624 - mean_squared_error: 0.0624 - val_loss: 0.0357 - val_mean_squared_error: 0.0357 - 15s/epoch - 19ms/step
# Epoch 15/500
# 792/792 - 15s - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - 15s/epoch - 19ms/step
# Epoch 16/500
# 792/792 - 15s - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0225 - val_mean_squared_error: 0.0225 - 15s/epoch - 19ms/step
# Epoch 17/500
# 792/792 - 15s - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - 15s/epoch - 19ms/step
# Epoch 18/500
# 792/792 - 15s - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - 15s/epoch - 19ms/step
# Epoch 19/500
# 792/792 - 15s - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - 15s/epoch - 19ms/step
# Epoch 20/500
# 792/792 - 15s - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0141 - val_mean_squared_error: 0.0141 - 15s/epoch - 19ms/step
# Epoch 21/500
# 792/792 - 15s - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - 15s/epoch - 19ms/step
# Epoch 22/500
# 792/792 - 15s - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 15s/epoch - 19ms/step
# Epoch 23/500
# 792/792 - 15s - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - 15s/epoch - 19ms/step
# Epoch 24/500
# 792/792 - 15s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 15s/epoch - 19ms/step
# Epoch 25/500
# 792/792 - 15s - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - 15s/epoch - 19ms/step
# Epoch 26/500
# 792/792 - 15s - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 15s/epoch - 19ms/step
# Epoch 27/500
# 792/792 - 15s - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0152 - val_mean_squared_error: 0.0152 - 15s/epoch - 19ms/step
# Epoch 28/500
# 792/792 - 15s - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 15s/epoch - 19ms/step
# Epoch 29/500
# 792/792 - 15s - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - 15s/epoch - 19ms/step
# Epoch 30/500
# 792/792 - 15s - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0163 - val_mean_squared_error: 0.0163 - 15s/epoch - 19ms/step
# Epoch 31/500
# 792/792 - 15s - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 15s/epoch - 19ms/step
# Epoch 32/500
# 792/792 - 15s - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - 15s/epoch - 19ms/step
# Epoch 33/500
# 792/792 - 15s - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - 15s/epoch - 19ms/step
# Epoch 34/500
# 792/792 - 15s - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - 15s/epoch - 19ms/step
# Epoch 35/500
# 792/792 - 15s - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0179 - val_mean_squared_error: 0.0179 - 15s/epoch - 19ms/step
# Epoch 36/500
# 792/792 - 15s - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 15s/epoch - 19ms/step
# Epoch 37/500
# 792/792 - 15s - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 15s/epoch - 19ms/step
# Epoch 38/500
# 792/792 - 15s - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - 15s/epoch - 19ms/step
# Epoch 39/500
# 792/792 - 15s - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 15s/epoch - 19ms/step
# Epoch 40/500
# 792/792 - 15s - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 15s/epoch - 19ms/step
# Epoch 41/500
# 792/792 - 15s - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 15s/epoch - 19ms/step
# Epoch 42/500
# 792/792 - 15s - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 15s/epoch - 19ms/step
# Epoch 43/500
# 792/792 - 15s - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0170 - val_mean_squared_error: 0.0170 - 15s/epoch - 19ms/step
# Epoch 44/500
# 792/792 - 15s - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 15s/epoch - 19ms/step
# Epoch 45/500
# 792/792 - 15s - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 15s/epoch - 19ms/step
# Epoch 46/500
# 792/792 - 15s - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 15s/epoch - 19ms/step
# Epoch 47/500
# 792/792 - 15s - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 15s/epoch - 19ms/step
# Epoch 48/500
# 792/792 - 15s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - 15s/epoch - 19ms/step
# Epoch 49/500
# 792/792 - 15s - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 15s/epoch - 19ms/step
# Epoch 50/500
# 792/792 - 15s - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 15s/epoch - 19ms/step
# Epoch 51/500
# 792/792 - 15s - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 15s/epoch - 19ms/step
# Epoch 52/500
# 792/792 - 15s - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 15s/epoch - 19ms/step
# Epoch 53/500
# 792/792 - 15s - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - 15s/epoch - 19ms/step
# Epoch 54/500
# 792/792 - 15s - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - 15s/epoch - 19ms/step
# Epoch 55/500
# 792/792 - 15s - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 15s/epoch - 19ms/step
# Epoch 56/500
# 792/792 - 15s - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 15s/epoch - 19ms/step
# Epoch 57/500
# 792/792 - 15s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 15s/epoch - 19ms/step
# Epoch 58/500
# 792/792 - 15s - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 15s/epoch - 19ms/step
# Epoch 59/500
# 792/792 - 15s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 15s/epoch - 19ms/step
# Epoch 60/500
# 792/792 - 15s - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 15s/epoch - 19ms/step
# Epoch 61/500
# 792/792 - 15s - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0074 - val_mean_squared_error: 0.0074 - 15s/epoch - 19ms/step
# Epoch 62/500
# 792/792 - 15s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 15s/epoch - 19ms/step
# Epoch 63/500
# 792/792 - 15s - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0276 - val_mean_squared_error: 0.0276 - 15s/epoch - 19ms/step
# Epoch 64/500
# 792/792 - 15s - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - 15s/epoch - 19ms/step
# Epoch 65/500
# 792/792 - 15s - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - 15s/epoch - 19ms/step
# Epoch 66/500
# 792/792 - 15s - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0077 - val_mean_squared_error: 0.0077 - 15s/epoch - 19ms/step
# Epoch 67/500
# 792/792 - 15s - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 15s/epoch - 19ms/step
# Epoch 68/500
# 792/792 - 15s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - 15s/epoch - 19ms/step
# Epoch 69/500
# 792/792 - 15s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - 15s/epoch - 19ms/step
# Epoch 70/500
# 792/792 - 15s - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 15s/epoch - 19ms/step
# Epoch 71/500
# 792/792 - 15s - loss: 0.0089 - mean_squared_error: 0.0089 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - 15s/epoch - 19ms/step
# Epoch 72/500
# 792/792 - 15s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 15s/epoch - 19ms/step
# Epoch 73/500
# 792/792 - 15s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 15s/epoch - 19ms/step
# Epoch 74/500
# 792/792 - 15s - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 15s/epoch - 19ms/step
# Epoch 75/500
# 792/792 - 15s - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 15s/epoch - 19ms/step
# Epoch 76/500
# 792/792 - 15s - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 15s/epoch - 19ms/step
# Epoch 77/500
# 792/792 - 15s - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 15s/epoch - 19ms/step
# Epoch 78/500
# 792/792 - 15s - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - 15s/epoch - 19ms/step
# Epoch 79/500
# 792/792 - 15s - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - 15s/epoch - 19ms/step
# Epoch 80/500
# 792/792 - 15s - loss: 0.0087 - mean_squared_error: 0.0087 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 15s/epoch - 19ms/step
# Epoch 81/500
# 792/792 - 15s - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 15s/epoch - 19ms/step
# Epoch 82/500
# 792/792 - 15s - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0074 - val_mean_squared_error: 0.0074 - 15s/epoch - 19ms/step
# Epoch 83/500
# 792/792 - 15s - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 15s/epoch - 19ms/step
# Epoch 84/500
# 792/792 - 15s - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 15s/epoch - 19ms/step
# Epoch 85/500
# 792/792 - 15s - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 15s/epoch - 19ms/step
# Epoch 86/500
# 792/792 - 15s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - 15s/epoch - 19ms/step
# Epoch 87/500
# 792/792 - 15s - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 15s/epoch - 19ms/step
# Epoch 88/500
# 792/792 - 15s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 15s/epoch - 19ms/step
# Epoch 89/500
# 792/792 - 15s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 15s/epoch - 19ms/step
# Epoch 90/500
# 792/792 - 15s - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0074 - val_mean_squared_error: 0.0074 - 15s/epoch - 19ms/step
# Epoch 91/500
# 792/792 - 15s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - 15s/epoch - 19ms/step
# Epoch 92/500
# 792/792 - 15s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 15s/epoch - 19ms/step
# Epoch 93/500
# 792/792 - 15s - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - 15s/epoch - 19ms/step
# Epoch 94/500
# 792/792 - 15s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - 15s/epoch - 19ms/step
# Epoch 95/500
# 792/792 - 15s - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 15s/epoch - 19ms/step
# Epoch 96/500
# 792/792 - 15s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 15s/epoch - 19ms/step
# Epoch 97/500
# 792/792 - 15s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - 15s/epoch - 19ms/step
# Epoch 98/500
# 792/792 - 15s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - 15s/epoch - 19ms/step
# Epoch 99/500
# 792/792 - 15s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 15s/epoch - 19ms/step
# Epoch 100/500
# 792/792 - 15s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 101/500
# 792/792 - 15s - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - 15s/epoch - 19ms/step
# Epoch 102/500
# 792/792 - 15s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 15s/epoch - 19ms/step
# Epoch 103/500
# 792/792 - 15s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0186 - val_mean_squared_error: 0.0186 - 15s/epoch - 19ms/step
# Epoch 104/500
# 792/792 - 15s - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 15s/epoch - 19ms/step
# Epoch 105/500
# 792/792 - 15s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 15s/epoch - 19ms/step
# Epoch 106/500
# 792/792 - 15s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - 15s/epoch - 19ms/step
# Epoch 107/500
# 792/792 - 15s - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - 15s/epoch - 19ms/step
# Epoch 108/500
# 792/792 - 15s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0075 - val_mean_squared_error: 0.0075 - 15s/epoch - 19ms/step
# Epoch 109/500
# 792/792 - 15s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 15s/epoch - 19ms/step
# Epoch 110/500
# 792/792 - 15s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 111/500
# 792/792 - 15s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 15s/epoch - 19ms/step
# Epoch 112/500
# 792/792 - 15s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - 15s/epoch - 19ms/step
# Epoch 113/500
# 792/792 - 15s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 114/500
# 792/792 - 15s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 15s/epoch - 19ms/step
# Epoch 115/500
# 792/792 - 15s - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 15s/epoch - 19ms/step
# Epoch 116/500
# 792/792 - 15s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 117/500
# 792/792 - 15s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0075 - val_mean_squared_error: 0.0075 - 15s/epoch - 19ms/step
# Epoch 118/500
# 792/792 - 15s - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - 15s/epoch - 19ms/step
# Epoch 119/500
# 792/792 - 15s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 15s/epoch - 19ms/step
# Epoch 120/500
# 792/792 - 15s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 15s/epoch - 19ms/step
# Epoch 121/500
# 792/792 - 15s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 15s/epoch - 19ms/step
# Epoch 122/500
# 792/792 - 15s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 123/500
# 792/792 - 15s - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 124/500
# 792/792 - 15s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 15s/epoch - 19ms/step
# Epoch 125/500
# 792/792 - 15s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 126/500
# 792/792 - 15s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 15s/epoch - 19ms/step
# Epoch 127/500
# 792/792 - 15s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 15s/epoch - 19ms/step
# Epoch 128/500
# 792/792 - 15s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - 15s/epoch - 19ms/step
# Epoch 129/500
# 792/792 - 15s - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 15s/epoch - 19ms/step
# Epoch 130/500
# 792/792 - 15s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 131/500
# 792/792 - 15s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 132/500
# 792/792 - 15s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 18ms/step
# Epoch 133/500
# 792/792 - 15s - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 134/500
# 792/792 - 15s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 135/500
# 792/792 - 15s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - 15s/epoch - 19ms/step
# Epoch 136/500
# 792/792 - 15s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 15s/epoch - 19ms/step
# Epoch 137/500
# 792/792 - 15s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0072 - val_mean_squared_error: 0.0072 - 15s/epoch - 19ms/step
# Epoch 138/500
# 792/792 - 15s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 15s/epoch - 19ms/step
# Epoch 139/500
# 792/792 - 15s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 15s/epoch - 19ms/step
# Epoch 140/500
# 792/792 - 15s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 15s/epoch - 19ms/step
# Epoch 141/500
# 792/792 - 15s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0072 - val_mean_squared_error: 0.0072 - 15s/epoch - 19ms/step
# Epoch 142/500
# 792/792 - 15s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 15s/epoch - 19ms/step
# Epoch 143/500
# 792/792 - 15s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - 15s/epoch - 19ms/step
# Epoch 144/500
# 792/792 - 15s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 145/500
# 792/792 - 15s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 15s/epoch - 19ms/step
# Epoch 146/500
# 792/792 - 15s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 147/500
# 792/792 - 15s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 15s/epoch - 19ms/step
# Epoch 148/500
# 792/792 - 15s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - 15s/epoch - 19ms/step
# Epoch 149/500
# 792/792 - 15s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 15s/epoch - 19ms/step
# Epoch 150/500
# 792/792 - 15s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 151/500
# 792/792 - 15s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 152/500
# 792/792 - 15s - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 153/500
# 792/792 - 15s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 15s/epoch - 19ms/step
# Epoch 154/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 15s/epoch - 19ms/step
# Epoch 155/500
# 792/792 - 15s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - 15s/epoch - 19ms/step
# Epoch 156/500
# 792/792 - 15s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 157/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 15s/epoch - 19ms/step
# Epoch 158/500
# 792/792 - 15s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 15s/epoch - 19ms/step
# Epoch 159/500
# 792/792 - 15s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - 15s/epoch - 19ms/step
# Epoch 160/500
# 792/792 - 15s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 161/500
# 792/792 - 15s - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - 15s/epoch - 19ms/step
# Epoch 162/500
# 792/792 - 15s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 163/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 164/500
# 792/792 - 15s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 165/500
# 792/792 - 15s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 15s/epoch - 19ms/step
# Epoch 166/500
# 792/792 - 15s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - 15s/epoch - 19ms/step
# Epoch 167/500
# 792/792 - 15s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 168/500
# 792/792 - 15s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - 15s/epoch - 19ms/step
# Epoch 169/500
# 792/792 - 15s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 15s/epoch - 19ms/step
# Epoch 170/500
# 792/792 - 15s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 171/500
# 792/792 - 15s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 15s/epoch - 19ms/step
# Epoch 172/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 15s/epoch - 19ms/step
# Epoch 173/500
# 792/792 - 15s - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 174/500
# 792/792 - 15s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 15s/epoch - 19ms/step
# Epoch 175/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 176/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 15s/epoch - 19ms/step
# Epoch 177/500
# 792/792 - 15s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 178/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 179/500
# 792/792 - 15s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 15s/epoch - 19ms/step
# Epoch 180/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 181/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 182/500
# 792/792 - 15s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0074 - val_mean_squared_error: 0.0074 - 15s/epoch - 19ms/step
# Epoch 183/500
# 792/792 - 15s - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0066 - val_mean_squared_error: 0.0066 - 15s/epoch - 19ms/step
# Epoch 184/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0077 - val_mean_squared_error: 0.0077 - 15s/epoch - 19ms/step
# Epoch 185/500
# 792/792 - 15s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - 15s/epoch - 19ms/step
# Epoch 186/500
# 792/792 - 15s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 187/500
# 792/792 - 15s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 188/500
# 792/792 - 15s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - 15s/epoch - 19ms/step
# Epoch 189/500
# 792/792 - 15s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 190/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 191/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 15s/epoch - 19ms/step
# Epoch 192/500
# 792/792 - 15s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 193/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 194/500
# 792/792 - 15s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 195/500
# 792/792 - 15s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0090 - val_mean_squared_error: 0.0090 - 15s/epoch - 19ms/step
# Epoch 196/500
# 792/792 - 15s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0180 - val_mean_squared_error: 0.0180 - 15s/epoch - 19ms/step
# Epoch 197/500
# 792/792 - 15s - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 198/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 199/500
# 792/792 - 15s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 200/500
# 792/792 - 15s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 201/500
# 792/792 - 15s - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 202/500
# 792/792 - 15s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 203/500
# 792/792 - 15s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 204/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 205/500
# 792/792 - 15s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - 15s/epoch - 19ms/step
# Epoch 206/500
# 792/792 - 15s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 207/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0181 - val_mean_squared_error: 0.0181 - 15s/epoch - 19ms/step
# Epoch 208/500
# 792/792 - 15s - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - 15s/epoch - 19ms/step
# Epoch 209/500
# 792/792 - 15s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - 15s/epoch - 19ms/step
# Epoch 210/500
# 792/792 - 15s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 211/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 15s/epoch - 19ms/step
# Epoch 212/500
# 792/792 - 15s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 15s/epoch - 19ms/step
# Epoch 213/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 214/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - 15s/epoch - 19ms/step
# Epoch 215/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 216/500
# 792/792 - 15s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 217/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 218/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0075 - val_mean_squared_error: 0.0075 - 15s/epoch - 19ms/step
# Epoch 219/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - 15s/epoch - 19ms/step
# Epoch 220/500
# 792/792 - 15s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 221/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - 15s/epoch - 19ms/step
# Epoch 222/500
# 792/792 - 15s - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 15s/epoch - 19ms/step
# Epoch 223/500
# 792/792 - 15s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 224/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0095 - val_mean_squared_error: 0.0095 - 15s/epoch - 19ms/step
# Epoch 225/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0077 - val_mean_squared_error: 0.0077 - 15s/epoch - 19ms/step
# Epoch 226/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 227/500
# 792/792 - 15s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 228/500
# 792/792 - 15s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 15s/epoch - 19ms/step
# Epoch 229/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - 15s/epoch - 19ms/step
# Epoch 230/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 231/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 232/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - 15s/epoch - 19ms/step
# Epoch 233/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 15s/epoch - 18ms/step
# Epoch 234/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 235/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0066 - val_mean_squared_error: 0.0066 - 15s/epoch - 19ms/step
# Epoch 236/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 237/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 238/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 239/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 240/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 241/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0072 - val_mean_squared_error: 0.0072 - 15s/epoch - 19ms/step
# Epoch 242/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 15s/epoch - 19ms/step
# Epoch 243/500
# 792/792 - 15s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 244/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - 15s/epoch - 19ms/step
# Epoch 245/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 246/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - 15s/epoch - 19ms/step
# Epoch 247/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 15s/epoch - 19ms/step
# Epoch 248/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 249/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 250/500
# 792/792 - 15s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 251/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 15s/epoch - 19ms/step
# Epoch 252/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 253/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - 15s/epoch - 19ms/step
# Epoch 254/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 255/500
# 792/792 - 15s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 256/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 15s/epoch - 19ms/step
# Epoch 257/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 258/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - 15s/epoch - 19ms/step
# Epoch 259/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - 15s/epoch - 19ms/step
# Epoch 260/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 261/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - 15s/epoch - 19ms/step
# Epoch 262/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 15s/epoch - 19ms/step
# Epoch 263/500
# 792/792 - 15s - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 264/500
# 792/792 - 15s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0072 - val_mean_squared_error: 0.0072 - 15s/epoch - 19ms/step
# Epoch 265/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 266/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0081 - val_mean_squared_error: 0.0081 - 15s/epoch - 19ms/step
# Epoch 267/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 268/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 269/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 270/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 271/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 272/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 273/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 274/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 275/500
# 792/792 - 15s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 276/500
# 792/792 - 15s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 277/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 278/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 279/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 280/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 281/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 282/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 283/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 284/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - 15s/epoch - 19ms/step
# Epoch 285/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 286/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 287/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - 15s/epoch - 19ms/step
# Epoch 288/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 289/500
# 792/792 - 15s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 290/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - 15s/epoch - 19ms/step
# Epoch 291/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 15s/epoch - 19ms/step
# Epoch 292/500
# 792/792 - 15s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 293/500
# 792/792 - 15s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 294/500
# 792/792 - 15s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 295/500
# 792/792 - 15s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 296/500
# 792/792 - 15s - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 297/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 298/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 299/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 300/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 301/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 302/500
# 792/792 - 15s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 303/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 304/500
# 792/792 - 15s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0066 - val_mean_squared_error: 0.0066 - 15s/epoch - 19ms/step
# Epoch 305/500
# 792/792 - 15s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 306/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 307/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 15s/epoch - 19ms/step
# Epoch 308/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 309/500
# 792/792 - 15s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - 15s/epoch - 19ms/step
# Epoch 310/500
# 792/792 - 15s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0089 - val_mean_squared_error: 0.0089 - 15s/epoch - 19ms/step
# Epoch 311/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - 15s/epoch - 19ms/step
# Epoch 312/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - 15s/epoch - 19ms/step
# Epoch 313/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 314/500
# 792/792 - 15s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 315/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - 15s/epoch - 19ms/step
# Epoch 316/500
# 792/792 - 15s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 317/500
# 792/792 - 15s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 318/500
# 792/792 - 15s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 15s/epoch - 19ms/step
# Epoch 319/500
# 792/792 - 15s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - 15s/epoch - 19ms/step
# Epoch 320/500
# 792/792 - 15s - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 321/500
# 792/792 - 15s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - 15s/epoch - 19ms/step
# Epoch 322/500
# 792/792 - 15s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 323/500
# ...
# Epoch 393/500
# 792/792 - 15s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 394/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 395/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0085 - val_mean_squared_error: 0.0085 - 15s/epoch - 19ms/step
# Epoch 396/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0072 - val_mean_squared_error: 0.0072 - 15s/epoch - 19ms/step
# Epoch 397/500
# 792/792 - 15s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 398/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 399/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 400/500
# 792/792 - 15s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 401/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - 15s/epoch - 19ms/step
# Epoch 402/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - 15s/epoch - 19ms/step
# Epoch 403/500
# 792/792 - 15s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 404/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0067 - val_mean_squared_error: 0.0067 - 15s/epoch - 19ms/step
# Epoch 405/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 406/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 407/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - 15s/epoch - 19ms/step
# Epoch 408/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 409/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 410/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - 15s/epoch - 19ms/step
# Epoch 411/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 412/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - 15s/epoch - 19ms/step
# Epoch 413/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0072 - val_mean_squared_error: 0.0072 - 15s/epoch - 19ms/step
# Epoch 414/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - 15s/epoch - 19ms/step
# Epoch 415/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 416/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 417/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - 15s/epoch - 19ms/step
# Epoch 418/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 419/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 15s/epoch - 19ms/step
# Epoch 420/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - 15s/epoch - 19ms/step
# Epoch 421/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 422/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0066 - val_mean_squared_error: 0.0066 - 15s/epoch - 19ms/step
# Epoch 423/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 15s/epoch - 19ms/step
# Epoch 424/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - 15s/epoch - 19ms/step
# Epoch 425/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 426/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 15s/epoch - 19ms/step
# Epoch 427/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 428/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 429/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 430/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0094 - val_mean_squared_error: 0.0094 - 15s/epoch - 19ms/step
# Epoch 431/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0068 - val_mean_squared_error: 0.0068 - 15s/epoch - 19ms/step
# Epoch 432/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 15s/epoch - 19ms/step
# Epoch 433/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 434/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 15s/epoch - 19ms/step
# Epoch 435/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 436/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 437/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 438/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - 15s/epoch - 19ms/step
# Epoch 439/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - 15s/epoch - 19ms/step
# Epoch 440/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 441/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 442/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 443/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0075 - val_mean_squared_error: 0.0075 - 15s/epoch - 19ms/step
# Epoch 444/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 15s/epoch - 19ms/step
# Epoch 445/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 446/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 447/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 448/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 15s/epoch - 19ms/step
# Epoch 449/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 19ms/step
# Epoch 450/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 15s/epoch - 19ms/step
# Epoch 451/500
# 792/792 - 15s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 452/500
# 792/792 - 15s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - 15s/epoch - 19ms/step
# Epoch 453/500
# 792/792 - 15s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - 15s/epoch - 19ms/step
# Epoch 454/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 455/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - 15s/epoch - 19ms/step
# Epoch 456/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 457/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 458/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 459/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 460/500
# 792/792 - 16s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 16s/epoch - 20ms/step
# Epoch 461/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 462/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0088 - val_mean_squared_error: 0.0088 - 15s/epoch - 19ms/step
# Epoch 463/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0063 - val_mean_squared_error: 0.0063 - 15s/epoch - 19ms/step
# Epoch 464/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 465/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - 15s/epoch - 19ms/step
# Epoch 466/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0076 - val_mean_squared_error: 0.0076 - 15s/epoch - 19ms/step
# Epoch 467/500
# 792/792 - 15s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - 15s/epoch - 19ms/step
# Epoch 468/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 469/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 19ms/step
# Epoch 470/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 471/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 472/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 18ms/step
# Epoch 473/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - 15s/epoch - 19ms/step
# Epoch 474/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - 15s/epoch - 18ms/step
# Epoch 475/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0071 - val_mean_squared_error: 0.0071 - 15s/epoch - 18ms/step
# Epoch 476/500
# 792/792 - 15s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 18ms/step
# Epoch 477/500
# 792/792 - 15s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - 15s/epoch - 19ms/step
# Epoch 478/500
# 792/792 - 15s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - 15s/epoch - 19ms/step
# Epoch 479/500
# 792/792 - 15s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0069 - val_mean_squared_error: 0.0069 - 15s/epoch - 19ms/step
# Epoch 480/500
# 792/792 - 15s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0080 - val_mean_squared_error: 0.0080 - 15s/epoch - 18ms/step
# Epoch 481/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 15s/epoch - 19ms/step
# Epoch 482/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 19ms/step
# Epoch 483/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 484/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 485/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 15s/epoch - 19ms/step
# Epoch 486/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - 15s/epoch - 19ms/step
# Epoch 487/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - 15s/epoch - 19ms/step
# Epoch 488/500
# 792/792 - 15s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0077 - val_mean_squared_error: 0.0077 - 15s/epoch - 20ms/step
# Epoch 489/500
# 792/792 - 15s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 490/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - 15s/epoch - 19ms/step
# Epoch 491/500
# 792/792 - 15s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - 15s/epoch - 19ms/step
# Epoch 492/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - 15s/epoch - 19ms/step
# Epoch 493/500
# 792/792 - 15s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0061 - val_mean_squared_error: 0.0061 - 15s/epoch - 19ms/step
# Epoch 494/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - 15s/epoch - 19ms/step
# Epoch 495/500
# 792/792 - 15s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - 15s/epoch - 18ms/step
# Epoch 496/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - 15s/epoch - 19ms/step
# Epoch 497/500
# 792/792 - 15s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 19ms/step
# Epoch 498/500
# 792/792 - 15s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 18ms/step
# Epoch 499/500
# 792/792 - 15s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - 15s/epoch - 18ms/step
# Epoch 500/500
# 792/792 - 15s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - 15s/epoch - 18ms/step

# %%
# Save completed model
model.save("mix-cnn-model_norm_w8_500")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: mix-cnn-model_norm_w8_500/assets
# INFO:tensorflow:Assets written to: mix-cnn-model_norm_w8_500/assets

# %%
# %tensorboard --logdir logs

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error'])

# %% [markdown]
# ## Validation

# %%
# Load model
model = keras.models.load_model("mix-cnn-model_w8_300")
# model = keras.models.load_model("mixmodel_w8_200")

# %%
y_hat = model.predict([X_testVolts_ds, X_testAmps_ds])
y_hat_plot = min_max_scaler.inverse_transform(y_hat.reshape((-1,1)))
y_test_plot = min_max_scaler.inverse_transform(y_test_ds.reshape((-1,1)))
# y_hat_plot = np.ravel(y_hat)
plt.plot(y_hat_plot*100)
plt.plot(y_test_plot*100, linewidth=3)
plt.legend(['Estimated W9', 'Actual W9'])
plt.xlabel("Datapoint [-]")
plt.ylabel("Capacity [%]")
plt.show()

model.evaluate([X_testVolts_ds, X_testAmps_ds], y_test_ds, verbose=2)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.xlabel("Epoch [-]")
plt.ylabel("Loss [%]")
plt.show()
# Out:
#   7/223 [..............................] - ETA: 1s
# 2022-05-25 14:32:14.987595: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 223/223 [==============================] - 1s 4ms/step
# 223/223 - 1s - loss: 0.0266 - mean_squared_error: 0.0266 - 1s/epoch - 5ms/step

# %%
y_hat_W10 = model.predict([X_testVolts_W10_ds, X_testAmps_W10_ds])
y_hat_plot_W10 = min_max_scaler.inverse_transform(y_hat_W10.reshape((-1,1)))
y_test_plot_W10 = min_max_scaler.inverse_transform(y_test_W10_ds.reshape((-1,1)))
# y_hat_plot_W10 = np.ravel(y_hat_W10)
plt.plot(y_hat_plot_W10)
plt.plot(y_test_plot_W10, linewidth=3)
plt.legend(['Estimated W10', 'Actual W10'])
plt.xlabel("Datapoint [-]")
plt.ylabel("Capacity [%]")
plt.show()
model.evaluate([X_testVolts_W10_ds, X_testAmps_W10_ds], y_test_W10_ds, verbose=2)
# Out:
# 231/231 [==============================] - 1s 4ms/step
# 231/231 - 1s - loss: 0.0362 - mean_squared_error: 0.0362 - 973ms/epoch - 4ms/step
# [0.036235932260751724, 0.036235932260751724]

# %%
y_hat_W5 = model.predict([X_testVolts_W5, X_testAmps_W5])
y_hat_plot_W5 = np.ravel(y_hat_W5)
plt.plot(y_hat_plot_W5)
plt.plot(y_test_W5, linewidth=3)
plt.legend(['Estimated W5', 'Actual W5'])
plt.xlabel("Datapoint [-]")
plt.ylabel("Capacity [%]")
plt.show()
model.evaluate([X_testVolts_W5, X_testAmps_W5], y_test_W5, verbose=2)
# Out:
# 2671/2671 [==============================] - 9s 4ms/step
# 2671/2671 - 12s - loss: 0.8480 - mean_squared_error: 0.8480 - 12s/epoch - 4ms/step
# [0.847960352897644, 0.847960352897644]
